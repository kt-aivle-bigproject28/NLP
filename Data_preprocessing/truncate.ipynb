# %%
import os
import zipfile

def extract_and_truncate(zip_path, output_dir, char_limit=20000):
    """
    Extracts a ZIP file and truncates text files to a specified character limit.
    
    :param zip_path: Path to the ZIP file.
    :param output_dir: Directory to save the extracted and truncated files.
    :param char_limit: Maximum number of characters per text file.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(output_dir)
    
    for root, _, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.txt'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                truncated_content = content[:char_limit]
                
                with open(file_path, 'w', encoding='utf-8') as f:
                    f.write(truncated_content)
                
                print(f"Processed: {file} (Truncated to {char_limit} chars)")

# Example usage
zip_path = r"C:\Users\User\Desktop\0108_데이터.zip"  # ZIP 파일 경로
output_folder = r"C:\Users\User\Desktop\data0108"  # 출력 폴더
extract_and_truncate(zip_path, output_folder)
# Out:
# Processed: 1. 브라운의 완벽한 고백 (이정석) (Z-Library).txt (Truncated to 20000 chars)
# Processed: Please Look After Mom (Korean Edition) (Kyung-Sook Shin) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 개미 1 (베르나르 베르베르  이세욱 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 개미 2 (베르나르 베르베르  이세욱 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 개미 3 (베르나르 베르베르  이세욱 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 개미 4 (베르나르 베르베르  이세욱 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 개미 5 (베르나르 베르베르  이세욱 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 그리스인 조르바 (니코스 카잔차키스 저, 이재형 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 그리스인 조르바 (영문판) (니코스 카잔차키스) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 그해 여름 끝 (옌롄커) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 김약국의 딸들 (박경리) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 나미야 잡화점의 기적 (히가시노 게이고) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 나와 너의 365일 (유이하 저, 김지연 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 남아 있는 나날 - 1989 부커상 수상작 (가즈오 이시구로) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 내가 틀릴 수도 있습니다 - 숲속의 현자가 전하는 마지막 인생 수업 (비욘 나티코 린데블라드) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 노랑무늬영원 (한강) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 노르웨이의 숲 (무라카미 하루키 저, 양억관 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 눈물을 마시는 새 1 (이영도) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 대도시의 사랑법 (박상영) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 더불어 숲 -세계 기행 (신영복) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 데미안 (헤르만 헤세  김인순 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 데미안 (헤르만 헤세) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 도쿄기담집 (무라카미 하루키) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 돈키호테 1 (미겔 데 세르반테스 사아베드라 안영옥 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 돈키호테 2 (미겔 데 세르반테스 사아베드라 안영옥 옮김) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 라이언, 내 곁에 있어줘 KAKAO FRIENDS series (전승환) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 무기의 그늘 (합본) (황석영) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 미야모토 무사시 1 - 땅의 장 (요시카와 에이지 저  강성욱 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 미야모토 무사시 10 - 원명의 장 (요시카와 에이지 저  강성욱 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 미야모토 무사시 2 - 물의 장 (요시카와 에이지 저  강성욱 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: 미야모토 무사시 3 - 불의 장 (요시카와 에이지 저  강성욱 역) (Z-Library).txt (Truncated to 20000 chars)
# Processed: